# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_min = np.min(x)
    x_max = np.max(x)
    norm = list()
    for i  in  x:
        norm.append((i - x_min) / (x_max - x_min))
    return np.array(norm)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    x_len = len(x)
    n_classes = 10
    one_hot = np.zeros((x_len,n_classes))
    one_hot[np.arange(x_len), x] = 1
    return (one_hot)
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function    
    return tf.placeholder(tf.float32, shape = [None, image_shape[0], image_shape[1], image_shape[2]], name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None, n_classes], name = 'y' )


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = 'keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    W = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],conv_num_outputs], stddev=0.1))
    b = tf.Variable(tf.zeros([conv_num_outputs]))
    out = tf.nn.conv2d(x_tensor, W, [1,conv_strides[0], conv_strides[1], 1], padding = 'SAME')
    out = tf.nn.bias_add(out, b)
    out = tf.nn.relu(out)
    out = tf.nn.max_pool(out,[1, pool_ksize[0], pool_ksize[1], 1],[1, pool_strides[0], pool_strides[1] , 1], padding = 'SAME')
    
    
    
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs, tf.nn.relu)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor,num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv1 = conv2d_maxpool(x, conv_num_outputs = 64, conv_ksize = (8,8), conv_strides = (4, 4), pool_ksize = (4,4), pool_strides = (2,2))
    conv2 = conv2d_maxpool(conv1, conv_num_outputs = 64, conv_ksize = (8,8), conv_strides = (4,4), pool_ksize = (4,4), pool_strides = (2,2))
    
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(conv2)
    flatten_layer = tf.nn.dropout(flatten_layer, keep_prob)
    
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc1 = fully_conn(flatten_layer, num_outputs = 256)
    fc2 = fully_conn(fc1, num_outputs = 128)
    fc3 = tf.nn.dropout(fc2,keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fc3, num_outputs =  10)
    
    
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {x : feature_batch, y : label_batch, keep_prob : keep_probability })
    pass 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost , feed_dict = {x : feature_batch, y : label_batch, keep_prob : 1.0})
    Accuracy =  session.run(accuracy , feed_dict = {x : valid_features, y : valid_labels, keep_prob : 1.0})
    print('loss : {:>10.4} Accuracy : {:.6f}'.format(loss,Accuracy))
    
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 64
batch_size = 128
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss :      2.168 Accuracy : 0.266000
# Epoch  2, CIFAR-10 Batch 1:  loss :      1.965 Accuracy : 0.361800
# Epoch  3, CIFAR-10 Batch 1:  loss :      1.893 Accuracy : 0.397200
# Epoch  4, CIFAR-10 Batch 1:  loss :      1.721 Accuracy : 0.427400
# Epoch  5, CIFAR-10 Batch 1:  loss :      1.611 Accuracy : 0.437000
# Epoch  6, CIFAR-10 Batch 1:  loss :      1.552 Accuracy : 0.443400
# Epoch  7, CIFAR-10 Batch 1:  loss :      1.514 Accuracy : 0.463400
# Epoch  8, CIFAR-10 Batch 1:  loss :      1.433 Accuracy : 0.466400
# Epoch  9, CIFAR-10 Batch 1:  loss :      1.372 Accuracy : 0.477400
# Epoch 10, CIFAR-10 Batch 1:  loss :       1.37 Accuracy : 0.475400
# Epoch 11, CIFAR-10 Batch 1:  loss :      1.223 Accuracy : 0.484000
# Epoch 12, CIFAR-10 Batch 1:  loss :      1.139 Accuracy : 0.486800
# Epoch 13, CIFAR-10 Batch 1:  loss :      1.169 Accuracy : 0.478800
# Epoch 14, CIFAR-10 Batch 1:  loss :       1.13 Accuracy : 0.497800
# Epoch 15, CIFAR-10 Batch 1:  loss :      1.023 Accuracy : 0.489600
# Epoch 16, CIFAR-10 Batch 1:  loss :     0.9629 Accuracy : 0.499200
# Epoch 17, CIFAR-10 Batch 1:  loss :     0.8781 Accuracy : 0.512400
# Epoch 18, CIFAR-10 Batch 1:  loss :      0.834 Accuracy : 0.491800
# Epoch 19, CIFAR-10 Batch 1:  loss :     0.8192 Accuracy : 0.510600
# Epoch 20, CIFAR-10 Batch 1:  loss :      0.774 Accuracy : 0.516600
# Epoch 21, CIFAR-10 Batch 1:  loss :     0.7275 Accuracy : 0.507200
# Epoch 22, CIFAR-10 Batch 1:  loss :     0.7686 Accuracy : 0.499600
# Epoch 23, CIFAR-10 Batch 1:  loss :     0.6945 Accuracy : 0.498400
# Epoch 24, CIFAR-10 Batch 1:  loss :     0.6876 Accuracy : 0.505200
# Epoch 25, CIFAR-10 Batch 1:  loss :     0.6248 Accuracy : 0.516800
# Epoch 26, CIFAR-10 Batch 1:  loss :     0.6644 Accuracy : 0.513600
# Epoch 27, CIFAR-10 Batch 1:  loss :     0.6142 Accuracy : 0.519800
# Epoch 28, CIFAR-10 Batch 1:  loss :     0.6244 Accuracy : 0.514000
# Epoch 29, CIFAR-10 Batch 1:  loss :     0.5886 Accuracy : 0.514400
# Epoch 30, CIFAR-10 Batch 1:  loss :     0.5636 Accuracy : 0.513800
# Epoch 31, CIFAR-10 Batch 1:  loss :     0.5874 Accuracy : 0.508200
# Epoch 32, CIFAR-10 Batch 1:  loss :     0.5107 Accuracy : 0.509000
# Epoch 33, CIFAR-10 Batch 1:  loss :     0.5317 Accuracy : 0.508200
# Epoch 34, CIFAR-10 Batch 1:  loss :     0.5154 Accuracy : 0.517000
# Epoch 35, CIFAR-10 Batch 1:  loss :     0.5277 Accuracy : 0.510200
# Epoch 36, CIFAR-10 Batch 1:  loss :     0.5118 Accuracy : 0.508600
# Epoch 37, CIFAR-10 Batch 1:  loss :     0.4789 Accuracy : 0.507400
# Epoch 38, CIFAR-10 Batch 1:  loss :     0.4981 Accuracy : 0.513600
# Epoch 39, CIFAR-10 Batch 1:  loss :      0.467 Accuracy : 0.514000
# Epoch 40, CIFAR-10 Batch 1:  loss :     0.4617 Accuracy : 0.502200
# Epoch 41, CIFAR-10 Batch 1:  loss :     0.4405 Accuracy : 0.513600
# Epoch 42, CIFAR-10 Batch 1:  loss :     0.4166 Accuracy : 0.511800
# Epoch 43, CIFAR-10 Batch 1:  loss :     0.4553 Accuracy : 0.507600
# Epoch 44, CIFAR-10 Batch 1:  loss :     0.4502 Accuracy : 0.507000
# Epoch 45, CIFAR-10 Batch 1:  loss :     0.4387 Accuracy : 0.501600
# Epoch 46, CIFAR-10 Batch 1:  loss :     0.4595 Accuracy : 0.501400
# Epoch 47, CIFAR-10 Batch 1:  loss :     0.4231 Accuracy : 0.495200
# Epoch 48, CIFAR-10 Batch 1:  loss :     0.4543 Accuracy : 0.509000
# Epoch 49, CIFAR-10 Batch 1:  loss :     0.3956 Accuracy : 0.507600
# Epoch 50, CIFAR-10 Batch 1:  loss :     0.4207 Accuracy : 0.507600
# Epoch 51, CIFAR-10 Batch 1:  loss :      0.388 Accuracy : 0.506200
# Epoch 52, CIFAR-10 Batch 1:  loss :     0.3561 Accuracy : 0.513400
# Epoch 53, CIFAR-10 Batch 1:  loss :      0.346 Accuracy : 0.505200
# Epoch 54, CIFAR-10 Batch 1:  loss :     0.3649 Accuracy : 0.499600
# Epoch 55, CIFAR-10 Batch 1:  loss :     0.3757 Accuracy : 0.503600
# Epoch 56, CIFAR-10 Batch 1:  loss :     0.3595 Accuracy : 0.499800
# Epoch 57, CIFAR-10 Batch 1:  loss :     0.3015 Accuracy : 0.515000
# Epoch 58, CIFAR-10 Batch 1:  loss :     0.2951 Accuracy : 0.502800
# Epoch 59, CIFAR-10 Batch 1:  loss :     0.3106 Accuracy : 0.512200
# Epoch 60, CIFAR-10 Batch 1:  loss :     0.4099 Accuracy : 0.484000
# Epoch 61, CIFAR-10 Batch 1:  loss :       0.31 Accuracy : 0.508600
# Epoch 62, CIFAR-10 Batch 1:  loss :     0.3203 Accuracy : 0.507000
# Epoch 63, CIFAR-10 Batch 1:  loss :     0.2956 Accuracy : 0.511800
# Epoch 64, CIFAR-10 Batch 1:  loss :     0.3287 Accuracy : 0.505400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss :      2.139 Accuracy : 0.288400
# Epoch  1, CIFAR-10 Batch 2:  loss :      1.887 Accuracy : 0.380000
# Epoch  1, CIFAR-10 Batch 3:  loss :      1.574 Accuracy : 0.391800
# Epoch  1, CIFAR-10 Batch 4:  loss :       1.63 Accuracy : 0.420800
# Epoch  1, CIFAR-10 Batch 5:  loss :      1.568 Accuracy : 0.443400
# Epoch  2, CIFAR-10 Batch 1:  loss :      1.617 Accuracy : 0.447000
# Epoch  2, CIFAR-10 Batch 2:  loss :      1.601 Accuracy : 0.456000
# Epoch  2, CIFAR-10 Batch 3:  loss :      1.294 Accuracy : 0.451800
# Epoch  2, CIFAR-10 Batch 4:  loss :      1.472 Accuracy : 0.482200
# Epoch  2, CIFAR-10 Batch 5:  loss :      1.464 Accuracy : 0.465000
# Epoch  3, CIFAR-10 Batch 1:  loss :      1.474 Accuracy : 0.489400
# Epoch  3, CIFAR-10 Batch 2:  loss :      1.443 Accuracy : 0.483200
# Epoch  3, CIFAR-10 Batch 3:  loss :      1.227 Accuracy : 0.470600
# Epoch  3, CIFAR-10 Batch 4:  loss :      1.396 Accuracy : 0.497000
# Epoch  3, CIFAR-10 Batch 5:  loss :      1.405 Accuracy : 0.478000
# Epoch  4, CIFAR-10 Batch 1:  loss :      1.371 Accuracy : 0.510400
# Epoch  4, CIFAR-10 Batch 2:  loss :      1.374 Accuracy : 0.514800
# Epoch  4, CIFAR-10 Batch 3:  loss :       1.14 Accuracy : 0.498600
# Epoch  4, CIFAR-10 Batch 4:  loss :      1.315 Accuracy : 0.516600
# Epoch  4, CIFAR-10 Batch 5:  loss :      1.248 Accuracy : 0.516800
# Epoch  5, CIFAR-10 Batch 1:  loss :      1.305 Accuracy : 0.521800
# Epoch  5, CIFAR-10 Batch 2:  loss :       1.29 Accuracy : 0.518600
# Epoch  5, CIFAR-10 Batch 3:  loss :      1.083 Accuracy : 0.514200
# Epoch  5, CIFAR-10 Batch 4:  loss :      1.218 Accuracy : 0.539800
# Epoch  5, CIFAR-10 Batch 5:  loss :       1.25 Accuracy : 0.510800
# Epoch  6, CIFAR-10 Batch 1:  loss :      1.192 Accuracy : 0.546600
# Epoch  6, CIFAR-10 Batch 2:  loss :      1.293 Accuracy : 0.540000
# Epoch  6, CIFAR-10 Batch 3:  loss :      1.059 Accuracy : 0.532200
# Epoch  6, CIFAR-10 Batch 4:  loss :      1.231 Accuracy : 0.533800
# Epoch  6, CIFAR-10 Batch 5:  loss :       1.23 Accuracy : 0.530200
# Epoch  7, CIFAR-10 Batch 1:  loss :      1.117 Accuracy : 0.544600
# Epoch  7, CIFAR-10 Batch 2:  loss :      1.274 Accuracy : 0.551200
# Epoch  7, CIFAR-10 Batch 3:  loss :      1.036 Accuracy : 0.531200
# Epoch  7, CIFAR-10 Batch 4:  loss :      1.177 Accuracy : 0.557000
# Epoch  7, CIFAR-10 Batch 5:  loss :      1.134 Accuracy : 0.537800
# Epoch  8, CIFAR-10 Batch 1:  loss :      1.081 Accuracy : 0.550400
# Epoch  8, CIFAR-10 Batch 2:  loss :      1.189 Accuracy : 0.553800
# Epoch  8, CIFAR-10 Batch 3:  loss :     0.9924 Accuracy : 0.564000
# Epoch  8, CIFAR-10 Batch 4:  loss :      1.145 Accuracy : 0.549400
# Epoch  8, CIFAR-10 Batch 5:  loss :      1.126 Accuracy : 0.560000
# Epoch  9, CIFAR-10 Batch 1:  loss :      1.037 Accuracy : 0.571000
# Epoch  9, CIFAR-10 Batch 2:  loss :      1.191 Accuracy : 0.567600
# Epoch  9, CIFAR-10 Batch 3:  loss :      0.961 Accuracy : 0.550200
# Epoch  9, CIFAR-10 Batch 4:  loss :      1.105 Accuracy : 0.576200
# Epoch  9, CIFAR-10 Batch 5:  loss :      1.022 Accuracy : 0.564600
# Epoch 10, CIFAR-10 Batch 1:  loss :     0.9917 Accuracy : 0.574600
# Epoch 10, CIFAR-10 Batch 2:  loss :      1.055 Accuracy : 0.574800
# Epoch 10, CIFAR-10 Batch 3:  loss :     0.9427 Accuracy : 0.568000
# Epoch 10, CIFAR-10 Batch 4:  loss :      1.071 Accuracy : 0.576800
# Epoch 10, CIFAR-10 Batch 5:  loss :      0.969 Accuracy : 0.569400
# Epoch 11, CIFAR-10 Batch 1:  loss :      1.005 Accuracy : 0.573000
# Epoch 11, CIFAR-10 Batch 2:  loss :      1.014 Accuracy : 0.573200
# Epoch 11, CIFAR-10 Batch 3:  loss :      0.889 Accuracy : 0.585400
# Epoch 11, CIFAR-10 Batch 4:  loss :      1.024 Accuracy : 0.576400
# Epoch 11, CIFAR-10 Batch 5:  loss :     0.9156 Accuracy : 0.577400
# Epoch 12, CIFAR-10 Batch 1:  loss :     0.8984 Accuracy : 0.583800
# Epoch 12, CIFAR-10 Batch 2:  loss :     0.9915 Accuracy : 0.582200
# Epoch 12, CIFAR-10 Batch 3:  loss :     0.9277 Accuracy : 0.565000
# Epoch 12, CIFAR-10 Batch 4:  loss :     0.9955 Accuracy : 0.577000
# Epoch 12, CIFAR-10 Batch 5:  loss :     0.9234 Accuracy : 0.580600
# Epoch 13, CIFAR-10 Batch 1:  loss :     0.9172 Accuracy : 0.591400
# Epoch 13, CIFAR-10 Batch 2:  loss :     0.9478 Accuracy : 0.588200
# Epoch 13, CIFAR-10 Batch 3:  loss :     0.9054 Accuracy : 0.563600
# Epoch 13, CIFAR-10 Batch 4:  loss :     0.9629 Accuracy : 0.576200
# Epoch 13, CIFAR-10 Batch 5:  loss :     0.8429 Accuracy : 0.592600
# Epoch 14, CIFAR-10 Batch 1:  loss :     0.8428 Accuracy : 0.592200
# Epoch 14, CIFAR-10 Batch 2:  loss :     0.9465 Accuracy : 0.595800
# Epoch 14, CIFAR-10 Batch 3:  loss :     0.8118 Accuracy : 0.579600
# Epoch 14, CIFAR-10 Batch 4:  loss :     0.9634 Accuracy : 0.591000
# Epoch 14, CIFAR-10 Batch 5:  loss :      0.855 Accuracy : 0.593400
# Epoch 15, CIFAR-10 Batch 1:  loss :     0.8455 Accuracy : 0.581000
# Epoch 15, CIFAR-10 Batch 2:  loss :     0.8769 Accuracy : 0.592600
# Epoch 15, CIFAR-10 Batch 3:  loss :     0.8075 Accuracy : 0.580800
# Epoch 15, CIFAR-10 Batch 4:  loss :     0.9329 Accuracy : 0.599800
# Epoch 15, CIFAR-10 Batch 5:  loss :     0.8416 Accuracy : 0.579200
# Epoch 16, CIFAR-10 Batch 1:  loss :     0.8504 Accuracy : 0.595600
# Epoch 16, CIFAR-10 Batch 2:  loss :     0.8686 Accuracy : 0.596800
# Epoch 16, CIFAR-10 Batch 3:  loss :     0.8195 Accuracy : 0.581400
# Epoch 16, CIFAR-10 Batch 4:  loss :     0.9086 Accuracy : 0.595600
# Epoch 16, CIFAR-10 Batch 5:  loss :     0.7332 Accuracy : 0.598200
# Epoch 17, CIFAR-10 Batch 1:  loss :     0.8247 Accuracy : 0.597000
# Epoch 17, CIFAR-10 Batch 2:  loss :     0.8289 Accuracy : 0.603600
# Epoch 17, CIFAR-10 Batch 3:  loss :     0.7984 Accuracy : 0.593200
# Epoch 17, CIFAR-10 Batch 4:  loss :     0.8829 Accuracy : 0.604000
# Epoch 17, CIFAR-10 Batch 5:  loss :     0.8034 Accuracy : 0.591400
# Epoch 18, CIFAR-10 Batch 1:  loss :     0.7941 Accuracy : 0.590800
# Epoch 18, CIFAR-10 Batch 2:  loss :     0.8574 Accuracy : 0.585200
# Epoch 18, CIFAR-10 Batch 3:  loss :     0.8097 Accuracy : 0.583800
# Epoch 18, CIFAR-10 Batch 4:  loss :     0.8436 Accuracy : 0.601800
# Epoch 18, CIFAR-10 Batch 5:  loss :     0.7281 Accuracy : 0.592000
# Epoch 19, CIFAR-10 Batch 1:  loss :     0.7603 Accuracy : 0.595000
# Epoch 19, CIFAR-10 Batch 2:  loss :     0.7845 Accuracy : 0.596800
# Epoch 19, CIFAR-10 Batch 3:  loss :     0.7352 Accuracy : 0.607400
# Epoch 19, CIFAR-10 Batch 4:  loss :     0.8673 Accuracy : 0.604400
# Epoch 19, CIFAR-10 Batch 5:  loss :     0.7125 Accuracy : 0.598800
# Epoch 20, CIFAR-10 Batch 1:  loss :     0.7316 Accuracy : 0.602600
# Epoch 20, CIFAR-10 Batch 2:  loss :      0.814 Accuracy : 0.600800
# Epoch 20, CIFAR-10 Batch 3:  loss :     0.6859 Accuracy : 0.607800
# Epoch 20, CIFAR-10 Batch 4:  loss :     0.7632 Accuracy : 0.604600
# Epoch 20, CIFAR-10 Batch 5:  loss :     0.6538 Accuracy : 0.594800
# Epoch 21, CIFAR-10 Batch 1:  loss :     0.7372 Accuracy : 0.598400
# Epoch 21, CIFAR-10 Batch 2:  loss :     0.7778 Accuracy : 0.606000
# Epoch 21, CIFAR-10 Batch 3:  loss :      0.734 Accuracy : 0.604800
# Epoch 21, CIFAR-10 Batch 4:  loss :     0.8396 Accuracy : 0.614400
# Epoch 21, CIFAR-10 Batch 5:  loss :     0.6431 Accuracy : 0.606600
# Epoch 22, CIFAR-10 Batch 1:  loss :     0.7341 Accuracy : 0.602000
# Epoch 22, CIFAR-10 Batch 2:  loss :     0.6932 Accuracy : 0.609400
# Epoch 22, CIFAR-10 Batch 3:  loss :     0.7294 Accuracy : 0.598000
# Epoch 22, CIFAR-10 Batch 4:  loss :     0.7467 Accuracy : 0.603400
# Epoch 22, CIFAR-10 Batch 5:  loss :     0.6849 Accuracy : 0.598600
# Epoch 23, CIFAR-10 Batch 1:  loss :     0.6913 Accuracy : 0.603200
# Epoch 23, CIFAR-10 Batch 2:  loss :     0.7052 Accuracy : 0.613200
# Epoch 23, CIFAR-10 Batch 3:  loss :     0.7487 Accuracy : 0.604200
# Epoch 23, CIFAR-10 Batch 4:  loss :     0.7979 Accuracy : 0.610200
# Epoch 23, CIFAR-10 Batch 5:  loss :     0.6599 Accuracy : 0.607400
# Epoch 24, CIFAR-10 Batch 1:  loss :     0.6936 Accuracy : 0.596200
# Epoch 24, CIFAR-10 Batch 2:  loss :     0.6901 Accuracy : 0.606000
# Epoch 24, CIFAR-10 Batch 3:  loss :     0.6881 Accuracy : 0.606400
# Epoch 24, CIFAR-10 Batch 4:  loss :     0.7963 Accuracy : 0.603600
# Epoch 24, CIFAR-10 Batch 5:  loss :     0.6047 Accuracy : 0.596600
# Epoch 25, CIFAR-10 Batch 1:  loss :     0.7048 Accuracy : 0.593800
# Epoch 25, CIFAR-10 Batch 2:  loss :     0.6756 Accuracy : 0.606600
# Epoch 25, CIFAR-10 Batch 3:  loss :     0.6681 Accuracy : 0.612200
# Epoch 25, CIFAR-10 Batch 4:  loss :     0.7806 Accuracy : 0.610000
# Epoch 25, CIFAR-10 Batch 5:  loss :     0.5917 Accuracy : 0.601400
# Epoch 26, CIFAR-10 Batch 1:  loss :     0.6818 Accuracy : 0.591000
# Epoch 26, CIFAR-10 Batch 2:  loss :     0.6743 Accuracy : 0.612600
# Epoch 26, CIFAR-10 Batch 3:  loss :     0.6442 Accuracy : 0.613800
# Epoch 26, CIFAR-10 Batch 4:  loss :     0.7758 Accuracy : 0.620400
# Epoch 26, CIFAR-10 Batch 5:  loss :     0.5802 Accuracy : 0.597800
# Epoch 27, CIFAR-10 Batch 1:  loss :      0.673 Accuracy : 0.608800
# Epoch 27, CIFAR-10 Batch 2:  loss :     0.6608 Accuracy : 0.612000
# Epoch 27, CIFAR-10 Batch 3:  loss :     0.6492 Accuracy : 0.614400
# Epoch 27, CIFAR-10 Batch 4:  loss :     0.7145 Accuracy : 0.612600
# Epoch 27, CIFAR-10 Batch 5:  loss :     0.5582 Accuracy : 0.602200
# Epoch 28, CIFAR-10 Batch 1:  loss :     0.6075 Accuracy : 0.599600
# Epoch 28, CIFAR-10 Batch 2:  loss :      0.697 Accuracy : 0.614000
# Epoch 28, CIFAR-10 Batch 3:  loss :     0.6633 Accuracy : 0.599200
# Epoch 28, CIFAR-10 Batch 4:  loss :     0.7214 Accuracy : 0.612000
# Epoch 28, CIFAR-10 Batch 5:  loss :     0.5706 Accuracy : 0.610200
# Epoch 29, CIFAR-10 Batch 1:  loss :     0.6209 Accuracy : 0.604200
# Epoch 29, CIFAR-10 Batch 2:  loss :     0.6298 Accuracy : 0.616200
# Epoch 29, CIFAR-10 Batch 3:  loss :     0.6221 Accuracy : 0.615000
# Epoch 29, CIFAR-10 Batch 4:  loss :     0.7051 Accuracy : 0.605600
# Epoch 29, CIFAR-10 Batch 5:  loss :     0.5547 Accuracy : 0.608400
# Epoch 30, CIFAR-10 Batch 1:  loss :     0.6251 Accuracy : 0.608000
# Epoch 30, CIFAR-10 Batch 2:  loss :     0.6314 Accuracy : 0.613400
# Epoch 30, CIFAR-10 Batch 3:  loss :     0.5958 Accuracy : 0.613400
# Epoch 30, CIFAR-10 Batch 4:  loss :     0.6773 Accuracy : 0.621600
# Epoch 30, CIFAR-10 Batch 5:  loss :     0.5046 Accuracy : 0.606200
# Epoch 31, CIFAR-10 Batch 1:  loss :     0.6251 Accuracy : 0.601800
# Epoch 31, CIFAR-10 Batch 2:  loss :     0.6628 Accuracy : 0.621200
# Epoch 31, CIFAR-10 Batch 3:  loss :     0.5979 Accuracy : 0.618000
# Epoch 31, CIFAR-10 Batch 4:  loss :     0.7165 Accuracy : 0.622800
# Epoch 31, CIFAR-10 Batch 5:  loss :     0.5494 Accuracy : 0.604200
# Epoch 32, CIFAR-10 Batch 1:  loss :     0.6131 Accuracy : 0.614600
# Epoch 32, CIFAR-10 Batch 2:  loss :     0.6735 Accuracy : 0.621400
# Epoch 32, CIFAR-10 Batch 3:  loss :     0.6294 Accuracy : 0.625000
# Epoch 32, CIFAR-10 Batch 4:  loss :     0.7231 Accuracy : 0.610600
# Epoch 32, CIFAR-10 Batch 5:  loss :     0.4917 Accuracy : 0.607200
# Epoch 33, CIFAR-10 Batch 1:  loss :     0.5771 Accuracy : 0.607000
# Epoch 33, CIFAR-10 Batch 2:  loss :     0.6306 Accuracy : 0.604400
# Epoch 33, CIFAR-10 Batch 3:  loss :     0.5797 Accuracy : 0.618600
# Epoch 33, CIFAR-10 Batch 4:  loss :     0.6694 Accuracy : 0.608200
# Epoch 33, CIFAR-10 Batch 5:  loss :     0.5118 Accuracy : 0.611600
# Epoch 34, CIFAR-10 Batch 1:  loss :     0.6077 Accuracy : 0.604600
# Epoch 34, CIFAR-10 Batch 2:  loss :     0.6223 Accuracy : 0.622600
# Epoch 34, CIFAR-10 Batch 3:  loss :     0.5768 Accuracy : 0.629600
# Epoch 34, CIFAR-10 Batch 4:  loss :     0.6592 Accuracy : 0.608000
# Epoch 34, CIFAR-10 Batch 5:  loss :     0.5208 Accuracy : 0.602400
# Epoch 35, CIFAR-10 Batch 1:  loss :     0.5693 Accuracy : 0.604600
# Epoch 35, CIFAR-10 Batch 2:  loss :     0.5883 Accuracy : 0.615600
# Epoch 35, CIFAR-10 Batch 3:  loss :     0.6117 Accuracy : 0.609800
# Epoch 35, CIFAR-10 Batch 4:  loss :     0.6918 Accuracy : 0.604000
# Epoch 35, CIFAR-10 Batch 5:  loss :     0.4656 Accuracy : 0.619400
# Epoch 36, CIFAR-10 Batch 1:  loss :     0.6245 Accuracy : 0.616000
# Epoch 36, CIFAR-10 Batch 2:  loss :     0.6163 Accuracy : 0.621200
# Epoch 36, CIFAR-10 Batch 3:  loss :     0.5819 Accuracy : 0.616400
# Epoch 36, CIFAR-10 Batch 4:  loss :      0.606 Accuracy : 0.612200
# Epoch 36, CIFAR-10 Batch 5:  loss :     0.4856 Accuracy : 0.622600
# Epoch 37, CIFAR-10 Batch 1:  loss :     0.5806 Accuracy : 0.612000
# Epoch 37, CIFAR-10 Batch 2:  loss :     0.5622 Accuracy : 0.630000
# Epoch 37, CIFAR-10 Batch 3:  loss :     0.6066 Accuracy : 0.615600
# Epoch 37, CIFAR-10 Batch 4:  loss :     0.6544 Accuracy : 0.609200
# Epoch 37, CIFAR-10 Batch 5:  loss :     0.4761 Accuracy : 0.603600
# Epoch 38, CIFAR-10 Batch 1:  loss :     0.6019 Accuracy : 0.610600
# Epoch 38, CIFAR-10 Batch 2:  loss :     0.6031 Accuracy : 0.612200
# Epoch 38, CIFAR-10 Batch 3:  loss :     0.5781 Accuracy : 0.623600
# Epoch 38, CIFAR-10 Batch 4:  loss :     0.6384 Accuracy : 0.615800
# Epoch 38, CIFAR-10 Batch 5:  loss :     0.4535 Accuracy : 0.628800
# Epoch 39, CIFAR-10 Batch 1:  loss :     0.5981 Accuracy : 0.614200
# Epoch 39, CIFAR-10 Batch 2:  loss :     0.5843 Accuracy : 0.625600
# Epoch 39, CIFAR-10 Batch 3:  loss :     0.5617 Accuracy : 0.619800
# Epoch 39, CIFAR-10 Batch 4:  loss :     0.6309 Accuracy : 0.610400
# Epoch 39, CIFAR-10 Batch 5:  loss :     0.4926 Accuracy : 0.611000
# Epoch 40, CIFAR-10 Batch 1:  loss :       0.57 Accuracy : 0.623000
# Epoch 40, CIFAR-10 Batch 2:  loss :     0.5716 Accuracy : 0.621200
# Epoch 40, CIFAR-10 Batch 3:  loss :     0.5209 Accuracy : 0.619400
# Epoch 40, CIFAR-10 Batch 4:  loss :     0.5833 Accuracy : 0.610000
# Epoch 40, CIFAR-10 Batch 5:  loss :     0.4532 Accuracy : 0.615000
# Epoch 41, CIFAR-10 Batch 1:  loss :     0.6036 Accuracy : 0.627600
# Epoch 41, CIFAR-10 Batch 2:  loss :     0.5568 Accuracy : 0.625400
# Epoch 41, CIFAR-10 Batch 3:  loss :     0.5587 Accuracy : 0.619000
# Epoch 41, CIFAR-10 Batch 4:  loss :     0.5747 Accuracy : 0.615000
# Epoch 41, CIFAR-10 Batch 5:  loss :     0.4628 Accuracy : 0.615200
# Epoch 42, CIFAR-10 Batch 1:  loss :     0.5486 Accuracy : 0.610000
# Epoch 42, CIFAR-10 Batch 2:  loss :     0.5274 Accuracy : 0.628800
# Epoch 42, CIFAR-10 Batch 3:  loss :     0.4688 Accuracy : 0.630800
# Epoch 42, CIFAR-10 Batch 4:  loss :     0.6541 Accuracy : 0.609600
# Epoch 42, CIFAR-10 Batch 5:  loss :     0.4758 Accuracy : 0.598200
# Epoch 43, CIFAR-10 Batch 1:  loss :     0.5838 Accuracy : 0.617000
# Epoch 43, CIFAR-10 Batch 2:  loss :     0.5476 Accuracy : 0.620600
# Epoch 43, CIFAR-10 Batch 3:  loss :     0.5121 Accuracy : 0.625800
# Epoch 43, CIFAR-10 Batch 4:  loss :       0.61 Accuracy : 0.615600
# Epoch 43, CIFAR-10 Batch 5:  loss :     0.4757 Accuracy : 0.618600
# Epoch 44, CIFAR-10 Batch 1:  loss :     0.5561 Accuracy : 0.619800
# Epoch 44, CIFAR-10 Batch 2:  loss :     0.4825 Accuracy : 0.618400
# Epoch 44, CIFAR-10 Batch 3:  loss :      0.578 Accuracy : 0.615600
# Epoch 44, CIFAR-10 Batch 4:  loss :     0.6312 Accuracy : 0.604800
# Epoch 44, CIFAR-10 Batch 5:  loss :     0.4306 Accuracy : 0.608400
# Epoch 45, CIFAR-10 Batch 1:  loss :     0.5741 Accuracy : 0.610800
# Epoch 45, CIFAR-10 Batch 2:  loss :      0.484 Accuracy : 0.624400
# Epoch 45, CIFAR-10 Batch 3:  loss :     0.5736 Accuracy : 0.622200
# Epoch 45, CIFAR-10 Batch 4:  loss :     0.6047 Accuracy : 0.618600
# Epoch 45, CIFAR-10 Batch 5:  loss :     0.4764 Accuracy : 0.609400
# Epoch 46, CIFAR-10 Batch 1:  loss :     0.5644 Accuracy : 0.621400
# Epoch 46, CIFAR-10 Batch 2:  loss :     0.5282 Accuracy : 0.608600
# Epoch 46, CIFAR-10 Batch 3:  loss :     0.5251 Accuracy : 0.616200
# Epoch 46, CIFAR-10 Batch 4:  loss :     0.5877 Accuracy : 0.611000
# Epoch 46, CIFAR-10 Batch 5:  loss :     0.4368 Accuracy : 0.624800
# Epoch 47, CIFAR-10 Batch 1:  loss :     0.5411 Accuracy : 0.627600
# Epoch 47, CIFAR-10 Batch 2:  loss :     0.5648 Accuracy : 0.622600
# Epoch 47, CIFAR-10 Batch 3:  loss :      0.553 Accuracy : 0.609400
# Epoch 47, CIFAR-10 Batch 4:  loss :     0.5742 Accuracy : 0.608000
# Epoch 47, CIFAR-10 Batch 5:  loss :      0.433 Accuracy : 0.620600
# Epoch 48, CIFAR-10 Batch 1:  loss :      0.546 Accuracy : 0.619800
# Epoch 48, CIFAR-10 Batch 2:  loss :     0.5117 Accuracy : 0.625200
# Epoch 48, CIFAR-10 Batch 3:  loss :     0.4312 Accuracy : 0.619800
# Epoch 48, CIFAR-10 Batch 4:  loss :     0.5596 Accuracy : 0.611600
# Epoch 48, CIFAR-10 Batch 5:  loss :     0.4197 Accuracy : 0.613200
# Epoch 49, CIFAR-10 Batch 1:  loss :      0.542 Accuracy : 0.625800
# Epoch 49, CIFAR-10 Batch 2:  loss :     0.5102 Accuracy : 0.618600
# Epoch 49, CIFAR-10 Batch 3:  loss :     0.4957 Accuracy : 0.605000
# Epoch 49, CIFAR-10 Batch 4:  loss :     0.5436 Accuracy : 0.608600
# Epoch 49, CIFAR-10 Batch 5:  loss :     0.3836 Accuracy : 0.614800
# Epoch 50, CIFAR-10 Batch 1:  loss :     0.5348 Accuracy : 0.618600
# Epoch 50, CIFAR-10 Batch 2:  loss :     0.5528 Accuracy : 0.613600
# Epoch 50, CIFAR-10 Batch 3:  loss :     0.4628 Accuracy : 0.622000
# Epoch 50, CIFAR-10 Batch 4:  loss :     0.5194 Accuracy : 0.613200
# Epoch 50, CIFAR-10 Batch 5:  loss :     0.4089 Accuracy : 0.607000
# Epoch 51, CIFAR-10 Batch 1:  loss :     0.4629 Accuracy : 0.618600
# Epoch 51, CIFAR-10 Batch 2:  loss :       0.53 Accuracy : 0.623400
# Epoch 51, CIFAR-10 Batch 3:  loss :     0.4648 Accuracy : 0.616400
# Epoch 51, CIFAR-10 Batch 4:  loss :     0.5524 Accuracy : 0.615200
# Epoch 51, CIFAR-10 Batch 5:  loss :     0.3866 Accuracy : 0.611000
# Epoch 52, CIFAR-10 Batch 1:  loss :     0.4594 Accuracy : 0.607000
# Epoch 52, CIFAR-10 Batch 2:  loss :     0.5155 Accuracy : 0.619200
# Epoch 52, CIFAR-10 Batch 3:  loss :     0.4809 Accuracy : 0.619400
# Epoch 52, CIFAR-10 Batch 4:  loss :     0.5423 Accuracy : 0.610400
# Epoch 52, CIFAR-10 Batch 5:  loss :     0.4246 Accuracy : 0.614400
# Epoch 53, CIFAR-10 Batch 1:  loss :     0.4867 Accuracy : 0.605200
# Epoch 53, CIFAR-10 Batch 2:  loss :      0.479 Accuracy : 0.615400
# Epoch 53, CIFAR-10 Batch 3:  loss :     0.4447 Accuracy : 0.615000
# Epoch 53, CIFAR-10 Batch 4:  loss :     0.5372 Accuracy : 0.609000
# Epoch 53, CIFAR-10 Batch 5:  loss :     0.3821 Accuracy : 0.620400
# Epoch 54, CIFAR-10 Batch 1:  loss :     0.4752 Accuracy : 0.615800
# Epoch 54, CIFAR-10 Batch 2:  loss :     0.5167 Accuracy : 0.625400
# Epoch 54, CIFAR-10 Batch 3:  loss :     0.4757 Accuracy : 0.611400
# Epoch 54, CIFAR-10 Batch 4:  loss :      0.581 Accuracy : 0.599800
# Epoch 54, CIFAR-10 Batch 5:  loss :     0.3898 Accuracy : 0.610000
# Epoch 55, CIFAR-10 Batch 1:  loss :     0.4871 Accuracy : 0.619600
# Epoch 55, CIFAR-10 Batch 2:  loss :     0.4495 Accuracy : 0.619200
# Epoch 55, CIFAR-10 Batch 3:  loss :     0.4515 Accuracy : 0.615200
# Epoch 55, CIFAR-10 Batch 4:  loss :     0.5455 Accuracy : 0.602200
# Epoch 55, CIFAR-10 Batch 5:  loss :     0.4221 Accuracy : 0.614800
# Epoch 56, CIFAR-10 Batch 1:  loss :     0.4401 Accuracy : 0.609000
# Epoch 56, CIFAR-10 Batch 2:  loss :     0.4441 Accuracy : 0.625200
# Epoch 56, CIFAR-10 Batch 3:  loss :     0.4254 Accuracy : 0.626800
# Epoch 56, CIFAR-10 Batch 4:  loss :     0.5051 Accuracy : 0.609200
# Epoch 56, CIFAR-10 Batch 5:  loss :     0.3867 Accuracy : 0.602600
# Epoch 57, CIFAR-10 Batch 1:  loss :      0.488 Accuracy : 0.610200
# Epoch 57, CIFAR-10 Batch 2:  loss :     0.5021 Accuracy : 0.612600
# Epoch 57, CIFAR-10 Batch 3:  loss :     0.4664 Accuracy : 0.610400
# Epoch 57, CIFAR-10 Batch 4:  loss :     0.4893 Accuracy : 0.619400
# Epoch 57, CIFAR-10 Batch 5:  loss :     0.4779 Accuracy : 0.601400
# Epoch 58, CIFAR-10 Batch 1:  loss :     0.4511 Accuracy : 0.602000
# Epoch 58, CIFAR-10 Batch 2:  loss :     0.4671 Accuracy : 0.617400
# Epoch 58, CIFAR-10 Batch 3:  loss :     0.4549 Accuracy : 0.613000
# Epoch 58, CIFAR-10 Batch 4:  loss :      0.538 Accuracy : 0.608200
# Epoch 58, CIFAR-10 Batch 5:  loss :     0.3738 Accuracy : 0.610000
# Epoch 59, CIFAR-10 Batch 1:  loss :     0.4665 Accuracy : 0.614000
# Epoch 59, CIFAR-10 Batch 2:  loss :     0.4486 Accuracy : 0.623000
# Epoch 59, CIFAR-10 Batch 3:  loss :     0.4346 Accuracy : 0.613400
# Epoch 59, CIFAR-10 Batch 4:  loss :     0.5076 Accuracy : 0.608600
# Epoch 59, CIFAR-10 Batch 5:  loss :     0.3801 Accuracy : 0.620400
# Epoch 60, CIFAR-10 Batch 1:  loss :     0.4423 Accuracy : 0.606800
# Epoch 60, CIFAR-10 Batch 2:  loss :     0.4384 Accuracy : 0.626400
# Epoch 60, CIFAR-10 Batch 3:  loss :     0.4284 Accuracy : 0.611200
# Epoch 60, CIFAR-10 Batch 4:  loss :     0.5218 Accuracy : 0.605200
# Epoch 60, CIFAR-10 Batch 5:  loss :       0.38 Accuracy : 0.619200
# Epoch 61, CIFAR-10 Batch 1:  loss :     0.4375 Accuracy : 0.611200
# Epoch 61, CIFAR-10 Batch 2:  loss :     0.4669 Accuracy : 0.624800
# Epoch 61, CIFAR-10 Batch 3:  loss :     0.4158 Accuracy : 0.609600
# Epoch 61, CIFAR-10 Batch 4:  loss :     0.4824 Accuracy : 0.612000
# Epoch 61, CIFAR-10 Batch 5:  loss :     0.3851 Accuracy : 0.609200
# Epoch 62, CIFAR-10 Batch 1:  loss :      0.418 Accuracy : 0.618400
# Epoch 62, CIFAR-10 Batch 2:  loss :     0.4125 Accuracy : 0.617200
# Epoch 62, CIFAR-10 Batch 3:  loss :     0.4362 Accuracy : 0.617000
# Epoch 62, CIFAR-10 Batch 4:  loss :     0.4994 Accuracy : 0.614800
# Epoch 62, CIFAR-10 Batch 5:  loss :     0.4484 Accuracy : 0.611400
# Epoch 63, CIFAR-10 Batch 1:  loss :     0.3862 Accuracy : 0.614200
# Epoch 63, CIFAR-10 Batch 2:  loss :     0.4429 Accuracy : 0.627000
# Epoch 63, CIFAR-10 Batch 3:  loss :     0.4228 Accuracy : 0.618400
# Epoch 63, CIFAR-10 Batch 4:  loss :     0.4439 Accuracy : 0.601800
# Epoch 63, CIFAR-10 Batch 5:  loss :     0.3479 Accuracy : 0.618600
# Epoch 64, CIFAR-10 Batch 1:  loss :     0.4766 Accuracy : 0.608600
# Epoch 64, CIFAR-10 Batch 2:  loss :     0.4112 Accuracy : 0.621200
# Epoch 64, CIFAR-10 Batch 3:  loss :     0.4435 Accuracy : 0.613400
# Epoch 64, CIFAR-10 Batch 4:  loss :     0.4754 Accuracy : 0.610000
# Epoch 64, CIFAR-10 Batch 5:  loss :      0.409 Accuracy : 0.593800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5971123417721519

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
